# %%
import json

# %%
with open('/Users/tnetha/Desktop/fips_code.txt','r') as f:
    fips = f.readlines()
fips = [x.strip() for x in fips]

# %%
data
# Out:
# {'data': [{'data': [['21.0'],
#     ['16.5'],
#     ['19.5'],
#     ['20.5'],
#     ['20.5'],
#     ['23.5'],
#     ['25.0'],
#     ['17.0'],
#     ['12.5'],
#     ['8.5'],
#     ['18.5'],
#     ['20.0'],
#     ['18.0'],
#     ['23.0'],
#     ['14.0'],
#     ['15.0'],
#     ['23.5'],
#     ['37.0'],
#     ['23.0'],
#     ['12.5'],
#     ['11.0'],
#     ['8.5'],
#     ['7.5'],
#     ['13.0'],
#     ['17.0'],
#     ['27.5'],
#     ['32.5'],
#     ['27.0'],
#     ['29.0'],
#     ['M'],
#     ['25.0'],
#     ['24.0'],
#     ['36.5'],
#     ['37.0'],
#     ['28.5'],
#     ['9.5'],
#     ['20.5'],
#     ['23.0'],
#     ['27.0'],
#     ['30.0'],
#     ['33.5'],
#     ['37.5'],
#     ['34.5'],
#     ['28.0'],
#     ['19.5'],
#     ['16.5'],
#     ['21.5'],
#     ['27.0'],
#     ['29.0'],
#     ['32.0'],
#     ['31.0'],
#     ['24.0'],
#     ['26.0'],
#     ['37.5'],
#     ['26.0'],
#     ['38.5'],
#     ['28.5'],
#     ['12.0'],
#     ['28.0'],
#     ['28.5'],
#     ['30.5'],
# ...

# %%
# Out:
# ['17001', '"2"', '17003', '"3"', '17005', '"4"', '17007', '"5"', '17009', '"6"', '17011', '"7"', '17013', '"8"', '17015', '"9"', '17017', '"10"', '17019', '"11"', '17021', '"12"', '17023', '"13"', '17025', '"14"', '17027', '"15"', '17029', '"16"', '17031', '"17"', '17033', '"18"', '17035', '"19"', '17037', '"20"', '17039', '"21"', '17041', '"22"', '17043', '"23"', '17045', '"24"', '17047', '"25"', '17049', '"26"', '17051', '"27"', '17053', '"28"', '17055', '"29"', '17057', '"30"', '17059', '"31"', '17061', '"32"', '17063', '"33"', '17065', '"34"', '17067', '"35"', '17069', '"36"', '17071', '"37"', '17073', '"38"', '17075', '"39"', '17077', '"40"', '17079', '"41"', '17081', '"42"', '17083', '"43"', '17085', '"44"', '17087', '"45"', '17089', '"46"', '17091', '"47"', '17093', '"48"', '17095', '"49"', '17097', '"50"', '17099', '"51"', '17101', '"52"', '17103', '"53"', '17105', '"54"', '17107', '"55"', '17109', '"56"', '17111', '"57"', '17113', '"58"', '17115', '"59"', '17117', '"60"', '1
# ...
